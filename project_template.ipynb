# %% [markdown]
# # Project Group 6
#
# Members:
# - Maartje janzen
# - Loes Pragt
# - Dominique van Toor
# - Rosanne de Jong
# - Sophie Timmerman
#
# Student numbers:
# - 4861701
# - 5204984
# - 4933400
# - 5373588
# - 5076870

# %% [markdown]
# Road traffic accounts for about 20% of total emissions in the Netherlands. Electric cars present an effective solution to reduce these emissions. An electric car does not produce emissions, such as nitrogen dioxide. In "Het Klimaatakkoord" (The Climate Agreement) of 2019, the government stated that the Netherlands must reduce CO2 emissions by 49% by 2030 and by 95% by 2050. Clean transportation is crucial to achieving these goals, and by 2040, all new passenger cars are required to be 100% electric. This means that these cars will run on electricity from a battery, hydrogen fuel cell, or solar panels (Rijksoverheid, n.d.).
#
# At the beginning of 2023, the Netherlands had more than 511,000 plug-in cars, accounting for about 6% of all passenger cars. Approximately 65% of these plug-in cars were fully electric, which means that about 4% of all passenger cars were fully electric (CBS, 2023). This is far from the government's targets for 2030 and 2050. To meet these goals, significant changes are needed, particularly in the infrastructure supporting electric vehicles. One key factor influencing the adoption of electric vehicles is the availability of charging points. Without sufficient and accessible charging infrastructure, the transition to 100% electric vehicles will be challenging, especially outside urban areas where access to charging points is more limited. This leads to the research question:

# %% [markdown]
# # Research Question
#
# *What is the impact of the availability of electric charging points on the usage of electric vehicles in the Netherlands?*

# %% [markdown]
# The availability of charging points can vary greatly depending on the region, which can significantly affect people's willingness to switch to electric cars. If they cannot charge their car, they simply will not use it. By identifying these regional differences, policymakers can improve the charging network for electric vehicles. This would help facilitate the transition to electric vehicles and ensure that clean transportation is accessible to everyone.

# %% [markdown]
# # Sub Questions
# - How does the availability of public versus private charging infrastructure differ between urban and rural areas in the Netherlands?
#     - What is the number of charging points per municipality in the Netherlands?
#     - How is this number divided between urban and non-urban areas?
# - What is the effect of the income of inhabitants in a municipality on the ratio of electric vehicles to charging points?
# - What is the ratio of electric vehicles owned by companies versus those owned by private households across different regions in the Netherlands?
#
#
# *The analysis focuses on data from January 1 2021, as this date is supported by detailed information from various sources. This specific reference point ensures consistency across our datasets, enabling us to effectively examine the distribution of charging points and electric vehicles and draw meaningful conclusions.*

# %% [markdown]
# # Elaboration on Subquestions
# *How does the availability of public versus private charging infrastructure differ between urban and rural areas of the Netherlands?*
#
# Public vs. Private charging stations
# - Public charging stations: these can be found in shared public spaces and have government support for reducing emissions in cities. Hypothesis: the availability is higher in urban areas.
# - Private charging stations: can only be used by the person who bought the charging station. Hypothesis: higher percentage in non-urban areas, since people have their own private driveways.
#
# Quantitative Analysis:
# - Spatial scale: municipalities categorized as urban or non-urban based on population density.
#
# Amount of charging points per municipality?
# - Database from the national charging infrastructure of the netherlands, shows the amount of charging points per municipality from july 2019 till 2024. It also shows it per province and the amount of private vs public charging points: https://www.agendalaadinfrastructuur.nl/monitoring+2021/monitoring+per+gemeente/default.aspx (NAL_Aantallen_Datasheet_2024-08.xlsx)
#
# Urban vs. Non-urban areas (we would like to have feedback about the options!)
# https://opendata.cbs.nl/statline/#/CBS/nl/dataset/70072NED/table?fromstatweb
# We have multiple options to get the urban and non-urban categories for the Netherlands. Since the data of the charging points is per province or per municipality, we have different options to categorize municipalities/provinces on urban or non-urban scale:
# - Option 1: Population density (capity per km^2) by province, this categorizes provinces based on average population density. It is easy to implement and interpret the data, but maybe too broad, it misses the urban/non-urban differences within provinces.

# %%
from IPython.display import Image
Image(filename=r"C:\Users\sophi\Downloads\foto1.png")

# %% [markdown]
# - Option 2: CBS Urbanization scale at provincial level, CBS uses address density in order to categorize provinces into five different urbanization levels. It is more nuanced than population density, but provinces can contain urban and non-urban areas, which makes this option maybe too general. We know the percentages of the urbanism scale in the provinces, but don't know where the charging points are located in the province, this makes it difficult. The five different urbanization scales are:
#     - very highly urban: average amount of 2500 or more addresses per km2;
#     - highly urban: average number of 1500 to 2500 addresses per km2;
#     - moderately urban: average number of 1000 to 1500 addresses per km2;
#     - little urban: average number of 500 to 1000 addresses per km2;
#     - non-urban: on average less than 500 addresses per km2.

# %%
from IPython.display import Image
Image(filename=r"C:\Users\sophi\Downloads\foto2.png")

# %% [markdown]
# - Option 3: We will categorize the whole provinces according to the CBS urban scale as mentioned above. We will categorize provinces to the 5 different scales and compare this data with the database of the charging points!

# %%
from IPython.display import Image
Image(filename=r"C:\Users\sophi\Downloads\foto3.png")

# %% [markdown]
# - Option 4: CBS urbanization scale at municipal level. We will categorize every municipality into the CBS urbanism scale (5 different kinds of urbanism levels). This provides the most accurate and detailed insight into urban vs. non-urban areas. Makes it more complex to implement but is the most precise option. The gaps in the data are municipalities that since 1995 (at the start of the database) have been merged. This seems like the best option.
#
# https://opendata.cbs.nl/statline/#/CBS/nl/dataset/70072NED/table?fromstatweb
#
# Approach:
# compare the availability of charging points with the urban scale and see if there is a correlation between the two.
#
# Result (are now done with he availability per capita and per km2 in the urban and in non-urban areas to identify discrepancies and trends, but can change depending on the chosen database):
#
# barchart or connected scatterplot: charging points per capita per province
# bar chart: compare the number of charging points (public vs. private) in urban vs. rural areas. x-axis: urban and non-urban, y-axis: amount of charging points. Bars: two groups (public vs. private)
# scatter plot: population density and the number of charging points per province (i think that per municipality is going to be wayyy to much). This also shows the correlation of the amount of charging points and the population density. x-axis: population density (capita per km2) y-axis: number of charging points. color: public vs. private charging stations
# if possible: heatmap, but i think that with the amount of databases we have it will be a bit difficult

# %%
from IPython.display import Image
Image(filename=r"C:\Users\sophi\Downloads\foto4.png")

# %% [markdown]
# *What is the effect of the income of inhabitants in a municipality on the ratio of electric vehicles and charging points?*
#
# Amount of charging points:
# https://www.agendalaadinfrastructuur.nl/monitoring+2021/monitoring+per+gemeente/default.aspx (NAL_Aantallen_Datasheet_2024-08.xlsx)
#
# Income of inhabitants of municipality:
# - Filtered for the year 2021
# https://www.cbs.nl/-/media/_excel/2024/21/inkomensverdeling-naar-gemeente-2015-tot-en-met-2022.xlsx
#
# The average amount of electric cars per household:
# - With the percentage of electric cars, the amount of electric cars can be calculated
#     - The average amount of cars per household per municipality
# https://www.cbs.nl/-/media/_excel/2024/08/gem-autobezit-huishouden_2023.xlsx (2023 en 2020 zijn te vinden, 2021 niet…)
#     - The average percentage of electric cars per household per municipality
# https://www.cbs.nl/nl-nl/longread/statistische-trends/2023/wie-rijdt-er-elektrisch-/3-resultaten#:~:text=In%2068%2C0%20procent%20van,die%20rijdt%20op%20fossiele%20brandstof. (3.3.4 Particuliere autobezitters met stekkerauto)
#
# Approach:
#
# Compare the income to the ratio of electric vehicles and charging points per municipality
#
# Result:
# - Trend line: x-axis represents the number of charging points per municipality, y-axis represents the number of electric cars per municipality.
# - Scatter plot with average income per municipality on the x-axis, and the ratio of electric vehicles to the number of charging points on the y-axis.

# %% [markdown]
# *What is the ratio of electric vehicles owned by companies versus those owned by private households across different regions in the Netherlands*
#
# https://klimaatmonitor.databank.nl/Jive?workspace_guid=7bbbff9b-7071-42ca-a1bc-e6973b5b75fd
#
# The database linked above provides information on the number of electric vehicles per municipality in the Netherlands. We are going to calculate the ratio of electric company cars to private cars for each municipality. By visualizing this ratio, the map aims to highlight trends and disparities in the adoption of electric vehicles across different municipalities. Higher ratios indicate a greater prevalence of electric company cars relative to private cars, suggesting stronger support for electric mobility in those areas. Below, you will find a data pipeline illustrating how we can utilize this data for further analysis.

# %% [markdown]
# # Contribution Statement
#
# *Be specific. Some of the tasks can be coding (expect everyone to do this), background research, conceptualisation, visualisation, data analysis, data modelling*
#
# To be included in the final report.

# %% [markdown]
# **Author 1**:
#
# **Author 2**:
#
# **Author 3**:

# %% [markdown]
# # Data Used

# %% [markdown]
# Number of charging points per province/municipality:
# https://www.agendalaadinfrastructuur.nl/monitoring+2021/monitoring+per+gemeente/default.aspx

# %% [markdown]
# # Data Pipeline

# %% [markdown]
# A logarithmic scale is currently used to reveal trends on the map; however, a more appropriate scale still needs to be applied.

# %%
import pandas as pd

path = r"C:\Users\sophi\Downloads\MijnProject\TIL6022-Programming\Elektrische en waterstofvoertuigen - Januari 2021 - Gemeenten.csv"
df = pd.read_csv(path)

print(df.head())
# Out:
#   Gemeenten;"Batterij-elektrische voertuigen (BEV) totaal  \
# 0  Aa en Hunze;269;131;1;139;2;0;126;2;131;0;0;0;...
# 1  Aalsmeer;438;203;0;260;14;0;147;17;203;0;0;0;0...
# 2     Aalten;259;80;0;73;12;0;171;3;80;0;0;0;0;0;0;0
# 3  Achtkarspelen;156;81;0;58;5;0;91;2;81;0;0;0;0;...
# 4  Alblasserdam;204;101;0;115;14;0;53;22;101;0;0;...
#
#     geregistreerd bij eigenaar|Januari 2021";"Plug-in hybride  voertuigen (PHEV) totaal  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#     geregistreerd bij eigenaar|Januari 2021";"Voertuigen op waterstof (FCEV) totaal  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
df = pd.read_csv(path, sep=';', quotechar='"')
df.set_index('Gemeenten', inplace=True)
df.rename(columns={
    "Elektrische personenauto's (BEV), geregistreerd bij eigenaar|Januari 2021": "Elektrische personenauto's 2021",
    "Elektrische bedrijfsauto's, geregistreerd bij eigenaar|Januari 2021": "Elektrische bedrijfsauto's 2021"
}, inplace=True)

# Selecteer de gewenste kolommen
data = df[["Elektrische personenauto's 2021", "Elektrische bedrijfsauto's 2021"]]

print(data.head())
data = df[["Elektrische personenauto's 2021", "Elektrische bedrijfsauto's 2021"]].copy()

# Bereken de verhouding en voeg deze als nieuwe kolom toe
data.loc[:, 'Bedrijf/Persoon Ratio'] = data["Elektrische bedrijfsauto's 2021"] / data["Elektrische personenauto's 2021"]

# Bekijk de eerste paar rijen van de data
print(data.head())
# Out:
#                Elektrische personenauto's 2021  \
# Gemeenten
# Aa en Hunze                                139
# Aalsmeer                                   260
# Aalten                                      73
# Achtkarspelen                               58
# Alblasserdam                               115
#
#                Elektrische bedrijfsauto's 2021
# Gemeenten
# Aa en Hunze                                  2
# Aalsmeer                                    14
# Aalten                                      12
# Achtkarspelen                                5
# Alblasserdam                                14
#                Elektrische personenauto's 2021  \
# Gemeenten
# Aa en Hunze                                139
# Aalsmeer                                   260
# Aalten                                      73
# Achtkarspelen                               58
# Alblasserdam                               115
#
#                Elektrische bedrijfsauto's 2021  Bedrijf/Persoon Ratio
# ...

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from owslib.wfs import WebFeatureService
from io import BytesIO
import requests
import numpy as np

# WFS-URL voor CBS gebiedsindelingen 2024
wfs_url = "https://service.pdok.nl/cbs/gebiedsindelingen/2024/wfs/v1_0"
wfs = WebFeatureService(url=wfs_url, version='1.0.0')

# Bekijk de beschikbare lagen
print(list(wfs.contents))

# Gebruik de laag voor de gemeentegrenzen
layer_name = 'gemeente_gegeneraliseerd'

# Stap 1: Maak een WFS-verzoek om de data als GeoJSON op te halen
params = dict(service='WFS', version='1.0.0', request='GetFeature', typename=layer_name, outputFormat='json')
response = requests.get(wfs_url, params=params)

# Controleer of het verzoek succesvol was
if response.status_code == 200:
    # Lees de GeoJSON in met GeoPandas
    gemeenten_gdf = gpd.read_file(BytesIO(response.content))
    
    # Bekijk de kolommen in de GeoDataFrame
    print(gemeenten_gdf.columns)

    # Bereken de verhouding en logaritmische verhouding
    data['Bedrijf/Persoon Ratio'] = data["Elektrische bedrijfsauto's 2021"] / data["Elektrische personenauto's 2021"]
    data['Log Bedrijf/Persoon Ratio'] = np.log1p(data['Bedrijf/Persoon Ratio'])  # Gebruik np.log1p voor log(1 + x)

    # Koppel de gegevens aan de geometrische gegevens van Nederland
    gemeenten_gdf = gemeenten_gdf.merge(data, left_on='statnaam', right_index=True, how='left')

    # Stap 4: Plot de gemeenten op de kaart met aangepaste kleuren
    fig, ax = plt.subplots(1, 1, figsize=(10, 10))
    gemeenten_gdf.plot(
        column='Log Bedrijf/Persoon Ratio',
        ax=ax,
        legend=True,
        cmap='YlOrRd',  # Kleurenschema dat geschikt is voor deze data
        scheme='quantiles',  # Gebruik kwantielen om de data in gelijke groepen te verdelen
        missing_kwds={'color': 'lightgrey', 'label': 'No data'}  # Gemeenten zonder data
    )
    

    ax.set_title('Logaritmische Verhouding Elektrische Bedrijfsauto\'s tot Personenauto\'s per Gemeente (2021)')
    plt.show()

else:
    print(f"Fout bij het ophalen van de gegevens: {response.status_code}")
# Out:
# ['arbeidsmarktregio_gegeneraliseerd', 'arbeidsmarktregio_labelpoint', 'arrondissementsgebied_gegeneraliseerd', 'arrondissementsgebied_labelpoint', 'buurt_gegeneraliseerd', 'buurt_labelpoint', 'buurt_niet_gegeneraliseerd', 'coropgebied_gegeneraliseerd', 'coropgebied_labelpoint', 'coropplusgebied_gegeneraliseerd', 'coropplusgebied_labelpoint', 'coropsubgebied_gegeneraliseerd', 'coropsubgebied_labelpoint', 'gemeente_gegeneraliseerd', 'gemeente_labelpoint', 'gemeente_niet_gegeneraliseerd', 'ggdregio_gegeneraliseerd', 'ggdregio_labelpoint', 'jeugdregio_gegeneraliseerd', 'jeugdregio_labelpoint', 'kamervankoophandelregio_gegeneraliseerd', 'kamervankoophandelregio_labelpoint', 'landbouwgebied_gegeneraliseerd', 'landbouwgebied_labelpoint', 'landbouwgroep_gegeneraliseerd', 'landbouwgroep_labelpoint', 'landsdeel_gegeneraliseerd', 'landsdeel_labelpoint', 'provincie_gegeneraliseerd', 'provincie_labelpoint', 'regionaalmeld_coordinatiepunt_gegeneraliseerd', 'regionaalmeld_coordinatiepunt_labelpoint
# ...
